# %% [markdown]
# # Encryption vs Hashing
#
# ## Learning Objective
#
# - I can explain the difference between encryption and hashing.
# - I can describe when encryption or hashing should be used to protect data.
# - I can give a real-world example of encryption and hashing.

# %% [markdown]
# ![The art of cracking codes](the_art_of_cracking_codes.png)

# %% [markdown]
# ## TLDR; (too long didn't read)
# **Encryption = lock & unlock 🔐 | Hashing = lock only 🔒**
# - Encryption can be reversed. Hashing cannot.
# - Both are usefule in different circumstances to protect your data e.g. your money!

# %% [markdown]
# ## Background Information
# Alan Turning, pressured into hacking the encrypted messages of the German Enigma machine during World War 2, developed what we consider to be the foundation of modern day computers. We call this a Turning Machine.
# I guess you could call Turning a famous **hacker!** but he was also a Cambridge professor of mathematics.
#
# To keep your online data safe (e.g. YOUR MONEY!) your bank will use Encryption and Hashing to protect your money.

# %% [markdown]
# ### Practical - Simple Book based Encryption
#
# [Practical: 02 Simple Book Key Encryption](02_practical_simple_book_key_encryption.ipynb)

# %% [markdown]
# ### Practical - Hashing
#
# [Practical: 03 Hashing Passwords](03_password_hashing.ipynb)

# %% [markdown]
# ### Practical - Encryption
#
# [Practical: 04 Encryption](04_encryption.ipynb)
